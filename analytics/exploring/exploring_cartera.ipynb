# %%
import os

import pandas as pd
import numpy as np

from dotenv import load_dotenv

from core_ds4a_project import cleaning, columns as project_columns, datasets

# %load_ext autoreload
# %autoreload 1
# %aimport core_ds4a_project, core_ds4a_project.cleaning, core_ds4a_project.columns, core_ds4a_project.datasets

pd.set_option("display.max_columns", None)

# %% [markdown]
# Environment variables:

# %%
load_dotenv('envvars')

ROOT_DATA_PATH = os.environ.get('ROOT_DATA_PATH')
RAW_DATA_PATH = os.environ.get('RAW_DATA_PATH') or f'{ROOT_DATA_PATH}/raw'

# %% [markdown]
# Reading data:

# %%
(cartera_df, clientes_df, colocacion_df) = datasets.read_joining_datasets(dir_path=RAW_DATA_PATH)

# %% [markdown]
# ## Questions

# %% [markdown]
# Question: what may be causing following inconsistencies?

# %%
cartera_df[['CLIENTE', 'OBLIGACION', 'FECHA_CIERRE', 'TIPO_CREDITO']].query('OBLIGACION == 219000654').sort_values(by='FECHA_CIERRE')
# Out:
#         CLIENTE  OBLIGACION FECHA_CIERRE TIPO_CREDITO
# 196124  FA21525   219000654   2021-08-31  RETANQUEADO

# %%
colocacion_df[['CLIENTE', 'OBLIGACION', 'TIPO_CREDITO']].query('OBLIGACION == 219000654')
# Out:
#    CLIENTE  OBLIGACION TIPO_CREDITO
# 0  FA21525   219000654     RENOVADO

# %% [markdown]
# Question: how does TIPO_CREDITO="RETANQUEADO" work?

# %%
cartera_df[['CLIENTE', 'OBLIGACION', 'FECHA_CIERRE', 'TIPO_CREDITO']].query('CLIENTE == "FA21525"').sort_values(by='FECHA_CIERRE')
# Out:
#         CLIENTE  OBLIGACION FECHA_CIERRE TIPO_CREDITO
# 718399  FA21525   179000123   2017-04-30  RETANQUEADO
# 228434  FA21525   179000123   2017-05-31  RETANQUEADO
# 170153  FA21525   179000123   2017-06-30  RETANQUEADO
# 533314  FA21525   179000123   2017-07-31  RETANQUEADO
# 210656  FA21525   179000123   2017-08-31  RETANQUEADO
# 645433  FA21525   179000123   2017-09-30  RETANQUEADO
# 704024  FA21525   179000123   2017-10-31  RETANQUEADO
# 398098  FA21525   179000123   2017-11-30  RETANQUEADO
# 333110  FA21525   179000123   2017-12-31  RETANQUEADO
# 761632  FA21525   179000123   2018-01-31  RETANQUEADO
# 386891  FA21525   179000123   2018-02-28  RETANQUEADO
# 679721  FA21525   179000123   2018-03-31  RETANQUEADO
# 624514  FA21525   179000814   2018-05-31     RENOVADO
# 787125  FA21525   179000814   2018-06-30     RENOVADO
# 640246  FA21525   179000814   2018-07-31     RENOVADO
# 79437   FA21525   179000814   2018-08-31     RENOVADO
# 1556    FA21525   179000814   2018-09-30     RENOVADO
# 586460  FA21525   179000814   2018-10-31     RENOVADO
# 442643  FA21525   179000814   2018-11-30     RENOVADO
# 415513  FA21525   179000814   2018-12-31     RENOVADO
# 144666  FA21525   179000814   2019-01-31     RENOVADO
# 353770  FA21525   179000814   2019-02-28     RENOVADO
# 225807  FA21525   179000814   2019-03-31     RENOVADO
# 746353  FA21525   179000814   2019-04-30     RENOVADO
# 196124  FA21525   219000654   2021-08-31  RETANQUEADO

# %%
# colocacion_df.query('OBLIGACION == 1914000203')
