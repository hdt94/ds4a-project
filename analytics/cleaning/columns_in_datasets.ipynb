# %% [markdown]
# This document presents some descriptions regarding the columns from datasets, considering:
# - There are multiple inconsistencies in naming of columns between files.
# - There is duplicated data between datasets.
# - No relational diagram was provided.
#
# This documents also explains some of the classifications of data columns in local package module `core_ds4a_project.columns`

# %% [markdown]
# Setting up notebook:

# %%
import glob
import json
import os

import pandas as pd
import numpy as np

from dotenv import load_dotenv

from core_ds4a_project import columns as project_columns
from core_ds4a_project.cleaning import normalize_columns_name, unique_columns_from_dataframes

# %load_ext autoreload
# %autoreload 1
# %aimport core_ds4a_project, core_ds4a_project.cleaning, core_ds4a_project.columns


pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 320)


# Environment variables
load_dotenv('envvars')
ROOT_DATA_PATH = os.environ.get('ROOT_DATA_PATH')
RAW_DATA_PATH = os.environ.get('RAW_DATA_PATH') or f'{ROOT_DATA_PATH}/raw'
CLEAN_DATA_PATH = os.environ.get('CLEAN_DATA_PATH') or f'{ROOT_DATA_PATH}/clean'

# %% [markdown]
# Reading data:
#
# > Note: ideally you would normalize columns just after reading each dataframe. This is not the case here considering raw columns are required to compose columns renaming dictionary.

# %%
def read_csv(file):
    df = pd.read_csv(file, sep=';', encoding="ISO-8859-1", nrows=1)
    return df


dataset_dfs_dict = {}
dataset_files_dict = {}  # used in later sections

file = glob.glob(f'{RAW_DATA_PATH}/*COLOCACION*.xlsx')[0]  # single file dataset
df = pd.read_excel(file, nrows=1, usecols='A:BB')
dataset_dfs_dict['COLOCACION_NEW'] = [df]

# csv_datasets = ['CARTERA', 'CONTACTO', 'NEGOCIO']
csv_datasets = ['CARTERA', 'COLOCACION', 'CONTACTO', 'NEGOCIO']
for dataset in csv_datasets:
    files = glob.glob(f'{RAW_DATA_PATH}/*{dataset}*.csv')
    dfs = [read_csv(f) for f in files]

    dataset_dfs_dict[dataset] = dfs
    dataset_files_dict[dataset] = files

# %% [markdown]
# ## Columns renaming dictionary

# %%
dataframes = [pd.concat(dfs) for dfs in dataset_dfs_dict.values()]
raw_columns = unique_columns_from_dataframes(dataframes)
normalized_columns = normalize_columns_name(raw_columns)

renaming_dict = {raw: norm for (raw, norm) in zip(raw_columns, normalized_columns)}
renaming_file = f'{ROOT_DATA_PATH}/dict-renaming-raw-columns.json'

with open(renaming_file, 'w', encoding='utf-8') as file:
    json.dump(renaming_dict, file, indent=4)

# %% [markdown]
# ## Columns dataframe

# %%
columns_series_list = []

for (dataset, dfs) in dataset_dfs_dict.items():
    for df in dfs:
        df.columns = normalize_columns_name(df.columns)

    unique_columns = unique_columns_from_dataframes(dfs)
    columns_series = pd.Series({c: True for c in unique_columns}, name=dataset)
    columns_series_list.append(columns_series)

columns_df = pd.concat(columns_series_list, axis=1).fillna(False).sort_index()
columns_df = columns_df[columns_df.columns.sort_values()]
columns_df.shape
# Out:
# (300, 5)

# %% [markdown]
# Complete columns dataframe is presented at last section.

# %% [markdown]
# Following is a cut version of columns dataframe useful for finding relations and duplicated columns between datasets:

# %%
columns_cut_df = (columns_df
    .copy()
    .drop(index=project_columns.NEGOCIO_PIVOTED_COLUMNS)
    .drop(columns=['COLOCACION'])  # old dataset
)

# 
columns_cut_df.loc[project_columns.CARTERA_USELESS_COLUMNS, 'CARTERA'] = False

counts_series = columns_cut_df.sum(axis=1).rename('COUNTS').astype(int)
columns_cut_df = pd.concat([columns_cut_df, counts_series], axis=1).query('COUNTS > 1')
columns_cut_df.shape
# Out:
# (28, 5)

# %%
columns_cut_df
# Out:
#                    CARTERA  COLOCACION_NEW  CONTACTO  NEGOCIO  COUNTS
# ASIGNADO_A           False           False      True     True       2
# CLIENTE               True           False      True     True       3
# COD_LINEA             True            True     False    False       2
# COD_MODALIDAD         True            True     False    False       2
# DIRECCION            False            True     False     True       2
# ESTADO               False            True     False     True       2
# ESTADO_CIVIL         False            True      True    False       2
# FECHA_APROBA          True            True     False    False       2
# FECHA_DESEMBOLSO      True            True     False    False       2
# FECHA_NACIMIENTO     False            True      True    False       2
# FECHA_SOLICITUD       True            True     False    False       2
# GENERO               False            True      True    False       2
# LINEA                 True            True     False    False       2
# MODALIDAD             True            True     False    False       2
# MONTO                 True            True     False    False       2
# NIVEL_ESTUDIOS       False            True      True    False       2
# OBLIGACION            True            True     False    False       2
# PERIODICIDAD_PAGO     True            True     False    False       2
# PROFESION            False            True      True    False       2
# REGION                True            True     False    False       2
# SUCURSAL             False            True      True    False       2
# SUCURSAL_COD          True            True     False    False       2
# TASA_ANUAL            True            True     False    False       2
# TIPO                  True           False     False     True       2
# TIPO_CREDITO          True            True     False    False       2
# TIPO_UBICACION        True            True      True    False       3
# TIPO_VIVIENDA        False            True      True    False       2
# VALOR_CUOTA           True            True     False    False       2

# %% [markdown]
# The following are the two main column identifier keys across datasets.
# - OBLIGACION: identifier that links CARTERA, CASTIGO and COLOCACION datasets.
# - CLIENTE (former "Homologacion Documento de Identidad"): identifier that links CARTERA, CONTACTO, and NEGOCIO datasets.

# %% [markdown]
# ## Columns in CARTERA dataset

# %% [markdown]
# CARTERA dataset is splitted into 56 files which some of them contain variable number of columns. Following are all available columns in CARTERA dataset along with the count of files in which each corresponding column is present:

# %%
cartera_columns_df = unique_columns_from_dataframes(dataframes=dataset_dfs_dict['CARTERA'],
                                                    return_column_df=True,
                                                    index=[os.path.basename(f) for f in dataset_files_dict['CARTERA']])

cartera_cols_counts = cartera_columns_df.sum(axis=0).rename('COUNTS')
cartera_cols_counts
# Out:
# BUS_REGION                  1
# CALIFICACION_CIERRE        56
# CAPITAL_VEN                56
# CEDULA                      3
# CELULAR                     2
# CLIENTE                    56
# COD_LINEA                  56
# COD_MODALIDAD              56
# COMISION                   56
# CORREO                      2
# CUOTAS_PACTADAS            56
# CUOTAS_PENDIENTES          56
# DIAS_VENCIDO               56
# DIRECCION                   2
# EDAD                        4
# EJECUTIVO_ACTUAL            1
# ESTADO_CIVIL                2
# ESTRATO                     4
# FACTORRH                    4
# FECHA_APROBA               56
# FECHA_DESEMBOLSO           56
# FECHA_NACIMIENTO            4
# FECHA_PROXIMO_PAGO         56
# FECHA_SOLICITUD            56
# FECHA_ULT_PAGO             56
# FECHA_UTL_ACTUALIZACION     2
# FECHA_VENCIMIENTO_FINAL    56
# GARANTIA_REAL              56
# GENERO                      4
# INTERES_VEN                56
# LINEA                      56
# MODALIDAD                  56
# MONTO                      56
# MORA                       56
# MUJER_CABEZA                4
# MUNICIPIO                   1
# MUNICIPIO_CLIENTE          56
# NIVEL_ESTUDIOS              4
# NOMBRE                      2
# NRO_SOLICITUD              56
# OBLIGACION                 56
# OTROS                      56
# PAGARE                     56
# PERIODICIDAD_PAGO          56
# PORCENTAJE_PAGO            56
# PROFESION                   4
# RANGO_PAGO                  1
# REGION                     56
# REGION_1                    1
# REGION_REAL                 1
# SALDO                      56
# SEGURO_VIDA                56
# SUCURSAL                    4
# SUCURSALES                  8
# SUCURSAL_1                  2
# SUCURSAL_COD               54
# SUCURSAL_REAL              53
# TASA_ANUAL                 56
# TASA_PERIODICA             56
# TEL_FIJO                    2
# TIPO                       56
# TIPO_CLIENTE               56
# TIPO_CLIENTE_COD           56
# TIPO_CREDITO               56
# TIPO_UBICACION             56
# VALOR_CUOTA                56
# VENCIDA                    56
# Name: COUNTS, dtype: int64

# %% [markdown]
# Columns in `core_ds4a_project.columns.CARTERA_USELESS_COLUMNS` correspond to columns from CARTERA dataset that are considered useless as they are present only in less than 10 out of 56 CARTERA files:
# > Notes:
# > - Columns EDAD and ESTRATO are present in COLOCATION dataset
# > - Columns ESTADO_CIVIL, FECHA_NACIMIENTO, NIVEL_ESTUDIOS, and PROFESION, are present in both COLOCACION and CONTACTO datasets.

# %%
cartera_cols_counts_less_than = cartera_cols_counts[cartera_cols_counts < 10].index
pd.Index(project_columns.CARTERA_USELESS_COLUMNS).equals(cartera_cols_counts_less_than)
# Out:
# True

# %%
project_columns.CARTERA_USELESS_COLUMNS
# Out:
# ['BUS_REGION',
#  'CEDULA',
#  'CELULAR',
#  'CORREO',
#  'DIRECCION',
#  'EDAD',
#  'EJECUTIVO_ACTUAL',
#  'ESTADO_CIVIL',
#  'ESTRATO',
#  'FACTORRH',
#  'FECHA_NACIMIENTO',
#  'FECHA_UTL_ACTUALIZACION',
#  'GENERO',
#  'MUJER_CABEZA',
#  'MUNICIPIO',
#  'NIVEL_ESTUDIOS',
#  'NOMBRE',
#  'PROFESION',
#  'RANGO_PAGO',
#  'REGION_1',
#  'REGION_REAL',
#  'SUCURSAL',
#  'SUCURSALES',
#  'SUCURSAL_1',
#  'TEL_FIJO']

# %% [markdown]
# ## Columns in NEGOCIO dataset

# %% [markdown]
# Columns in `core_ds4a_project.columns.NEGOCIO_PIVOTED_COLUMNS` correspond to columns that have been pivoted. Those pivoted columns are only present in NEGOCIO dataset.

# %%
# Match any NEGOCIO pivoted column
regex = '|'.join([f'({col})' for col in project_columns.NEGOCIO_PIVOTED_COLUMNS])
index = columns_df.index.str.match(regex)

only_in_negocio = (columns_df.loc[index,'NEGOCIO'] & columns_df[index].sum(axis=1) == 1).all()
only_in_negocio
# Out:
# True

# %%
project_columns.NEGOCIO_PIVOTED_COLUMNS
# Out:
# ['CANTIDAD_DE_INVENTARIO_1',
#  'CANTIDAD_DE_INVENTARIO_2',
#  'CANTIDAD_DE_INVENTARIO_3',
#  'CANTIDAD_DE_INVENTARIO_4',
#  'CANTIDAD_DE_INVENTARIO_5',
#  'CANTIDAD_DE_INVENTARIO_6',
#  'DESCRIPCION_DEL_ACREEDOR_1',
#  'DESCRIPCION_DEL_ACREEDOR_2',
#  'DESCRIPCION_DEL_ACREEDOR_3',
#  'DESCRIPCION_DEL_ACREEDOR_4',
#  'DESCRIPCION_DEL_ACTIVO_FIJO_1',
#  'DESCRIPCION_DEL_ACTIVO_FIJO_2',
#  'DESCRIPCION_DEL_ACTIVO_FIJO_3',
#  'DESCRIPCION_DEL_PRODUCTO_1',
#  'DESCRIPCION_DEL_PRODUCTO_2',
#  'DESCRIPCION_DEL_PRODUCTO_3',
#  'DESCRIPCION_DEL_PRODUCTO_4',
#  'DESCRIPCION_DEL_PRODUCTO_5',
#  'DESCRIPCION_DEL_PRODUCTO_6',
#  'DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_1',
#  'DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_2',
#  'DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_3',
#  'DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_4',
#  'DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_5',
#  'DESTINO_DEL_PASIVO_1',
#  'DESTINO_DEL_PASIVO_2',
#  'DESTINO_DEL_PASIVO_3',
#  'DESTINO_DEL_PASIVO_4',
#  'ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PRENDA_1',
#  'ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PRENDA_2',
#  'ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PRENDA_3',
#  'FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_1',
#  'FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_2',
#  'FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_3',
#  'FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_1',
#  'FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_2',
#  'FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_3',
#  'FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_4',
#  'INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_1',
#  'INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_2',
#  'INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_3',
#  'INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOCIO_O_SON_DE_LOS_BIENES_DE_LA_UNIDAD_FAMILIAR_1',
#  'INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOCIO_O_SON_DE_LOS_BIENES_DE_LA_UNIDAD_FAMILIAR_2',
#  'INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOCIO_O_SON_DE_LOS_BIENES_DE_LA_UNIDAD_FAMILIAR_3',
#  'INGRESO_ABRIL',
#  'INGRESO_AGOSTO',
#  'INGRESO_DICIEMBRE',
#  'INGRESO_ENERO',
#  'INGRESO_FEBRERO',
#  'INGRESO_JULIO',
#  'INGRESO_JUNIO',
#  'INGRESO_MARZO',
#  'INGRESO_MAYO',
#  'INGRESO_NOVIEMBRE',
#  'INGRESO_OCTUBRE',
#  'INGRESO_SEPTIEMBRE',
#  'MODELO_DEL_VEHICULO_1',
#  'MODELO_DEL_VEHICULO_2',
#  'MODELO_DEL_VEHICULO_3',
#  'MONTO_DE_LA_DEUDA_1',
#  'MONTO_DE_LA_DEUDA_2',
#  'MONTO_DE_LA_DEUDA_3',
#  'MONTO_DE_LA_DEUDA_4',
#  'NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE_EL_TIPO_DE_ACTIVO_SEA_INMUEBLES_1',
#  'NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE_EL_TIPO_DE_ACTIVO_SEA_INMUEBLES_2',
#  'NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE_EL_TIPO_DE_ACTIVO_SEA_INMUEBLES_3',
#  'NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIVOS_SEA_VEHICULO_1',
#  'NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIVOS_SEA_VEHICULO_2',
#  'NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIVOS_SEA_VEHICULO_3',
#  'NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PARTE_DE_LA_GARANTIA_1',
#  'NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PARTE_DE_LA_GARANTIA_2',
#  'NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PARTE_DE_LA_GARANTIA_3',
#  'NUMERO_DE_UNIDADES_VENDIDAS_1',
#  'NUMERO_DE_UNIDADES_VENDIDAS_2',
#  'NUMERO_DE_UNIDADES_VENDIDAS_3',
#  'NUMERO_DE_UNIDADES_VENDIDAS_4',
#  'NUMERO_DE_UNIDADES_VENDIDAS_5',
#  'OBSERVACIONES_DEL_ACTIVO_FIJO_1',
#  'OBSERVACIONES_DEL_ACTIVO_FIJO_2',
#  'OBSERVACIONES_DEL_ACTIVO_FIJO_3',
#  'TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_1',
#  'TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_2',
#  'TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_3',
#  'TIPO_DE_INVENTARIO_1',
#  'TIPO_DE_INVENTARIO_2',
#  'TIPO_DE_INVENTARIO_3',
#  'TIPO_DE_INVENTARIO_4',
#  'TIPO_DE_INVENTARIO_5',
#  'TIPO_DE_INVENTARIO_6',
#  'TIPO_DE_PASIVO_1',
#  'TIPO_DE_PASIVO_2',
#  'TIPO_DE_PASIVO_3',
#  'TIPO_DE_PASIVO_4',
#  'VALOR_COMERCIAL_1',
#  'VALOR_COMERCIAL_2',
#  'VALOR_COMERCIAL_3',
#  'VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_1',
#  'VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_2',
#  'VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_3',
#  'VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_4',
#  'VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_5',
#  'VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUCTO_1',
#  'VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUCTO_2',
#  'VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUCTO_3',
#  'VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUCTO_4',
#  'VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUCTO_5',
#  'VALOR_DE_LA_CUOTA_1',
#  'VALOR_DE_LA_CUOTA_2',
#  'VALOR_DE_LA_CUOTA_3',
#  'VALOR_DE_LA_CUOTA_4',
#  'VALOR_DE_LA_CUOTA_ACTUAL_1',
#  'VALOR_DE_LA_CUOTA_ACTUAL_2',
#  'VALOR_DE_LA_CUOTA_ACTUAL_3',
#  'VALOR_DE_LA_CUOTA_ACTUAL_4',
#  'VALOR_DE_LA_GARANTIA_1',
#  'VALOR_DE_LA_GARANTIA_2',
#  'VALOR_DE_LA_GARANTIA_3',
#  'VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_1',
#  'VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_2',
#  'VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_3',
#  'VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_SOCIO-ECONOMICO_1',
#  'VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_SOCIO-ECONOMICO_2',
#  'VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_SOCIO-ECONOMICO_3',
#  'VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_SOCIO-ECONOMICO_4',
#  'VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_SOCIO-ECONOMICO_5',
#  'VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_SOCIO-ECONOMICO_6']

# %% [markdown]
# ## Comparing CONTACTO and NEGOCIO

# %% [markdown]
# > Note: `core_ds4a_project.columns.NEGOCIO_PIVOTED_COLUMNS` have been compacted for visualization purposes by replacing last number or word for a "PIVOTED", but such compacted columns are not actually part of NEGOCIO dataset.

# %%
contacto_negocio_cols_df = (columns_df
    [['CONTACTO', 'NEGOCIO']]
    .drop(index=project_columns.NEGOCIO_PIVOTED_COLUMNS)
    .query('CONTACTO | NEGOCIO')
)

# Compacting pivoted columns
pattern = r'^(?P<col>.*)_\w*$'
negocio_pivoted_cols = (pd.Series(project_columns.NEGOCIO_PIVOTED_COLUMNS)
                        .str.replace(pattern, lambda m: m.group('col') + '_PIVOTED', regex=True)
                        .drop_duplicates()
                        )
negocio_pivoted_cols_df = pd.DataFrame([True for c in negocio_pivoted_cols],
                  columns=['NEGOCIO'],
                  index=negocio_pivoted_cols)

pd.concat([contacto_negocio_cols_df, negocio_pivoted_cols_df]).fillna(False).sort_index()
# Out:
#                                                     CONTACTO  NEGOCIO
# ACTIVIDAD                                              False     True
# ACTIVIDAD_CIIU_PRIMARIA                                 True    False
# ACTIVIDAD_ECONOMICA                                     True    False
# ADMINISTRA_RECURSOS_PUBLICOS                            True    False
# ARRENDADOR_DEL_NEGOCIO                                 False     True
# ASIGNADO_A                                              True     True
# AUTORIZA_EL_ENVIO_DE_INFORMACION_POR_MEDIO_DE_C...      True    False
# AUTORIZA_LA_CONSULTA_EN_LAS_CENTRALES_DE_RIESGO         True    False
# BANCO_MONEDA_EXTRANJERA                                 True    False
# BARRIO                                                 False     True
# BARRIO_COMERCIAL                                        True    False
# BARRIO_RESIDENCIA                                       True    False
# CANTIDAD_DE_INVENTARIO_PIVOTED                         False     True
# CENTRO_DE_COSTO                                         True    False
# CIUDAD                                                 False     True
# CIUDAD_COMERCIAL                                        True    False
# CIUDAD_EMPRESA                                          True    False
# CIUDAD_RESIDENCIA                                       True    False
# CLIENTE                                                 True     True
# CODIGO_DEL_CAMPO_ADICIONAL_DEL_NEGOCIO                 False     True
# CUENTA_MONEDA_EXTRANJERA                                True    False
# DECLARA_RENTA                                           True    False
# DESCRIPCION                                            False     True
# DESCRIPCION_DEL_ACREEDOR_PIVOTED                       False     True
# DESCRIPCION_DEL_ACTIVO_FIJO_PIVOTED                    False     True
# DESCRIPCION_DEL_PRODUCTO_PIVOTED                       False     True
# DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_PIVOTED      False     True
# DESCRIPCION_DE_LAS_OPERACIONES_EN_MONEDA_EXTRAN...      True    False
# DESCRIPCION_OTROS_INGRESOS                              True    False
# DESTINO_DEL_PASIVO_PIVOTED                             False     True
# DIAS_LABORADOS_POR_SEMANA                              False     True
# DIRECCION                                              False     True
# DIRECCION_COMERCIAL                                     True    False
# DIRECCION_DE_RESIDENCIA                                 True    False
# DIRECCION_EMPRESA                                       True    False
# DIR_CORRESPONDENCIA                                     True    False
# EGRESOS_MENSUALES                                       True    False
# EMAIL                                                   True    False
# EMPRESA_DONDE_TRABAJA                                   True    False
# ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PREN...     False     True
# ENTIDAD_FINANCIERA                                      True    False
# ESTADO                                                 False     True
# ESTADO_CIVIL                                            True    False
# FAX                                                     True    False
# FAX_EMPRESA                                             True    False
# FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_PIVOTED           False     True
# FECHA_DE_EXPEDICION_CEDULA                              True    False
# FECHA_DE_INICIO_DEL_NEGOCIO                            False     True
# FECHA_EN_EL_ACTUAL_LUGAR_DE_UBICACION                  False     True
# FECHA_NACIMIENTO                                        True    False
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_PIVOTED               False     True
# GENERO                                                  True    False
# INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_PIVOTED        False     True
# INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOC...     False     True
# INGRESO_MENSUAL                                         True    False
# INGRESO_PIVOTED                                        False     True
# JORNADA_LABORAL                                         True    False
# LUGAR_DE_EXPEDICION                                     True    False
# MEDIO_DE_PAGO                                           True    False
# METODO_DEL_CALCULO_DE_COSTO_DE_VENTA                   False     True
# MODELO_DEL_VEHICULO_PIVOTED                            False     True
# MONEDA                                                  True    False
# MONTO_DE_LA_DEUDA_PIVOTED                              False     True
# MOVIL                                                   True    False
# MUJER_CABEZA                                            True    False
# NATURALEZA                                              True    False
# NIVEL_ESTUDIOS                                          True    False
# NOMBRE_DEL_CARGO_QUE_DESEMPENA_EN_LA_EMPRESA            True    False
# NOMBRE_DEL_NEGOCIO                                     False     True
# NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE...     False     True
# NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIV...     False     True
# NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PAR...     False     True
# NUMERO_DE_UNIDADES_VENDIDAS_PIVOTED                    False     True
# OBSERVACIONES_DEL_ACTIVO_FIJO_PIVOTED                  False     True
# OCUPACION                                               True    False
# OFICIO                                                  True    False
# OTROS_INGRESOS                                          True    False
# PAIS_MONEDA_EXTRANJERA                                  True    False
# PERSONA_FALLECIDA                                       True    False
# POBLACION_VULNERABLE                                    True    False
# POSEE_CUENTAS_EN_MONEDA_EXTRANJERA                      True    False
# PROFESION                                               True    False
# REALIZA_OPERACIONES_EN_MONEDA_EXTRANJERA                True    False
# REFERENCIA_UBICACION_DEL_NEGOCIO                       False     True
# REGIMEN_DE_IMPUESTOS                                    True    False
# REGIMEN_DE_IVA                                          True    False
# REGIMEN_DE_RENTA                                        True    False
# REGIONAL                                                True    False
# RESPONSABLE_DE_HOGAR                                    True    False
# SUCURSAL                                                True    False
# SUELDO_BASICO                                           True    False
# TELEFONO                                               False     True
# TELEFONO_EMPRESA                                        True    False
# TELEFONO_PARTICULAR                                     True    False
# TIPO                                                   False     True
# TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO...     False     True
# TIPO_DE_CLIENTE                                         True    False
# TIPO_DE_CONTRATO                                        True    False
# TIPO_DE_CONTRIBUYENTE                                   True    False
# TIPO_DE_CUENTA_BANCARIA                                 True    False
# TIPO_DE_IDENTIFICACION                                  True    False
# TIPO_DE_INVENTARIO_PIVOTED                             False     True
# TIPO_DE_PASIVO_PIVOTED                                 False     True
# TIPO_DE_VENTAS_QUE_REALIZA                             False     True
# TIPO_UBICACION                                          True    False
# TIPO_VIVIENDA                                           True    False
# UBICACION_2                                             True    False
# VALOR_COMERCIAL_PIVOTED                                False     True
# VALOR_DEL_CAMPO_ADICIONAL                              False     True
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_PIVOTED          False     True
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...     False     True
# VALOR_DE_LA_CUOTA_ACTUAL_PIVOTED                       False     True
# VALOR_DE_LA_CUOTA_PIVOTED                              False     True
# VALOR_DE_LA_GARANTIA_PIVOTED                           False     True
# VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_PIVOTED               False     True
# VALOR_OTROS_DESCUENTOS_DE_NOMINA                        True    False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...     False     True
# VENCIMIENTO_DEL_CONTRATO                                True    False
# ZONA                                                   False     True

# %% [markdown]
# ## Complete columns dataframe

# %%
counts_series = columns_df.sum(axis=1).rename('COUNTS').astype(int)
pd.concat([columns_df, counts_series], axis=1)
# Out:
#                                                     CARTERA  COLOCACION  \
# ACTIVIDAD                                             False       False
# ACTIVIDAD_CIIU_PRIMARIA                               False       False
# ACTIVIDAD_ECONOMICA                                   False       False
# ADMINISTRA_RECURSOS_PUBLICOS                          False       False
# ANO_CONTABILIZA                                       False       False
# ARRENDADOR_DEL_NEGOCIO                                False       False
# ASIGNADO_A                                            False       False
# AUTORIZA_EL_ENVIO_DE_INFORMACION_POR_MEDIO_DE_C...    False       False
# AUTORIZA_LA_CONSULTA_EN_LAS_CENTRALES_DE_RIESGO       False       False
# BANCO_MONEDA_EXTRANJERA                               False       False
# BARRIO                                                False       False
# BARRIO_COMERCIAL                                      False       False
# BARRIO_NEGOCIO                                        False        True
# BARRIO_RESIDENCIA                                     False       False
# BUS_REGION                                             True       False
# CALIFICACION_CIERRE                                    True        True
# CANTIDAD_DE_INVENTARIO_1                              False       False
# CANTIDAD_DE_INVENTARIO_2                              False       False
# CANTIDAD_DE_INVENTARIO_3                              False       False
# CANTIDAD_DE_INVENTARIO_4                              False       False
# CANTIDAD_DE_INVENTARIO_5                              False       False
# CANTIDAD_DE_INVENTARIO_6                              False       False
# CAPITAL_VEN                                            True        True
# CEDULA                                                 True       False
# CELULAR                                                True        True
# CENTRO_DE_COSTO                                       False       False
# CIUDAD                                                False       False
# CIUDAD_COMERCIAL                                      False       False
# CIUDAD_EMPRESA                                        False       False
# CIUDAD_RESIDENCIA                                     False       False
# CLIENTE                                                True        True
# CODEUDOR                                              False        True
# CODIGO_DEL_CAMPO_ADICIONAL_DEL_NEGOCIO                False       False
# COD_DESTINACION                                       False       False
# COD_LINEA                                              True        True
# COD_MODALIDAD                                          True        True
# COD_USUARIO_APR                                       False       False
# COMISION                                               True        True
# CORREO                                                 True        True
# CREDITOS_VIGENTES                                     False       False
# CUENTA_MONEDA_EXTRANJERA                              False       False
# CUOTAS_PACTADAS                                        True        True
# CUOTAS_PENDIENTES                                      True        True
# DECLARA_RENTA                                         False       False
# DESCRIPCION                                           False       False
# DESCRIPCION_DEL_ACREEDOR_1                            False       False
# DESCRIPCION_DEL_ACREEDOR_2                            False       False
# DESCRIPCION_DEL_ACREEDOR_3                            False       False
# DESCRIPCION_DEL_ACREEDOR_4                            False       False
# DESCRIPCION_DEL_ACTIVO_FIJO_1                         False       False
# DESCRIPCION_DEL_ACTIVO_FIJO_2                         False       False
# DESCRIPCION_DEL_ACTIVO_FIJO_3                         False       False
# DESCRIPCION_DEL_PRODUCTO_1                            False       False
# DESCRIPCION_DEL_PRODUCTO_2                            False       False
# DESCRIPCION_DEL_PRODUCTO_3                            False       False
# DESCRIPCION_DEL_PRODUCTO_4                            False       False
# DESCRIPCION_DEL_PRODUCTO_5                            False       False
# DESCRIPCION_DEL_PRODUCTO_6                            False       False
# DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_1           False       False
# DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_2           False       False
# DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_3           False       False
# DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_4           False       False
# DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_5           False       False
# DESCRIPCION_DE_LAS_OPERACIONES_EN_MONEDA_EXTRAN...    False       False
# DESCRIPCION_OTROS_INGRESOS                            False       False
# DESTINACION                                           False       False
# DESTINO_DEL_PASIVO_1                                  False       False
# DESTINO_DEL_PASIVO_2                                  False       False
# DESTINO_DEL_PASIVO_3                                  False       False
# DESTINO_DEL_PASIVO_4                                  False       False
# DIAS_CICLO_CREDITO                                    False       False
# DIAS_LABORADOS_POR_SEMANA                             False       False
# DIAS_VENCIDO                                           True        True
# DIRECCION                                              True        True
# DIRECCION_COMERCIAL                                   False       False
# DIRECCION_DE_RESIDENCIA                               False       False
# DIRECCION_EMPRESA                                     False       False
# DIR_CORRESPONDENCIA                                   False       False
# DIR_NEGOCIO                                           False        True
# DOC_CONTABILIZA                                       False       False
# EDAD                                                   True        True
# EGRESOS_MENSUALES                                     False       False
# EJECUTIVO_ACTUAL                                       True       False
# EMAIL                                                 False       False
# EMPRESA_DONDE_TRABAJA                                 False       False
# ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PREN...    False       False
# ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PREN...    False       False
# ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PREN...    False       False
# ENTIDAD_FINANCIERA                                    False       False
# ESTADO                                                False       False
# ESTADO_CIVIL                                           True        True
# ESTRATO                                                True        True
# EST_SOLICITUD                                         False       False
# FACTORRH                                               True        True
# FAX                                                   False       False
# FAX_EMPRESA                                           False       False
# FECHA_APROBA                                           True        True
# FECHA_DESEMBOLSO                                       True        True
# FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_1                False       False
# FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_2                False       False
# FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_3                False       False
# FECHA_DE_EXPEDICION_CEDULA                            False       False
# FECHA_DE_INICIO_DEL_NEGOCIO                           False       False
# FECHA_EN_EL_ACTUAL_LUGAR_DE_UBICACION                 False       False
# FECHA_NACIMIENTO                                       True        True
# FECHA_PAGO                                            False       False
# FECHA_PROXIMO_PAGO                                     True        True
# FECHA_SOLICITUD                                        True        True
# FECHA_ULT_PAGO                                         True        True
# FECHA_UTL_ACTUALIZACION                                True        True
# FECHA_VENCIMIENTO_FINAL                                True        True
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_1                    False       False
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_2                    False       False
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_3                    False       False
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_4                    False       False
# GARANTIA_REAL                                          True        True
# GENERO                                                 True        True
# IDENTI_EJECUTIVO                                      False       False
# INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_1             False       False
# INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_2             False       False
# INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_3             False       False
# INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOC...    False       False
# INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOC...    False       False
# INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOC...    False       False
# INGRESO_ABRIL                                         False       False
# INGRESO_AGOSTO                                        False       False
# INGRESO_DICIEMBRE                                     False       False
# INGRESO_ENERO                                         False       False
# INGRESO_FEBRERO                                       False       False
# INGRESO_JULIO                                         False       False
# INGRESO_JUNIO                                         False       False
# INGRESO_MARZO                                         False       False
# INGRESO_MAYO                                          False       False
# INGRESO_MENSUAL                                       False       False
# INGRESO_NOVIEMBRE                                     False       False
# INGRESO_OCTUBRE                                       False       False
# INGRESO_SEPTIEMBRE                                    False       False
# INTERES_VEN                                            True        True
# JORNADA_LABORAL                                       False       False
# K_ZONA_NEG                                            False        True
# LINEA                                                  True        True
# LUGAR_DE_EXPEDICION                                   False       False
# MEDIO_DE_PAGO                                         False       False
# METODO_DEL_CALCULO_DE_COSTO_DE_VENTA                  False       False
# MODALIDAD                                              True        True
# MODELO_DEL_VEHICULO_1                                 False       False
# MODELO_DEL_VEHICULO_2                                 False       False
# MODELO_DEL_VEHICULO_3                                 False       False
# MONEDA                                                False       False
# MONTO                                                  True        True
# MONTO_DE_LA_DEUDA_1                                   False       False
# MONTO_DE_LA_DEUDA_2                                   False       False
# MONTO_DE_LA_DEUDA_3                                   False       False
# MONTO_DE_LA_DEUDA_4                                   False       False
# MORA                                                   True        True
# MOVIL                                                 False       False
# MUJER_CABEZA                                           True        True
# MUNICIPIO                                              True       False
# MUNICIPIO_CLIENTE                                      True        True
# NATURALEZA                                            False       False
# NEGOCIO                                               False        True
# NIVEL_ESTUDIOS                                         True        True
# NOMBRE                                                 True       False
# NOMBRE_DEL_CARGO_QUE_DESEMPENA_EN_LA_EMPRESA          False       False
# NOMBRE_DEL_NEGOCIO                                    False       False
# NOMBRE_EJECUTIVO                                      False       False
# NOMBRE_USUARIO                                        False       False
# NRO_CUOTAS                                            False       False
# NRO_SOLICITUD                                          True        True
# NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE...    False       False
# NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE...    False       False
# NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE...    False       False
# NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIV...    False       False
# NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIV...    False       False
# NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIV...    False       False
# NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PAR...    False       False
# NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PAR...    False       False
# NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PAR...    False       False
# NUMERO_DE_UNIDADES_VENDIDAS_1                         False       False
# NUMERO_DE_UNIDADES_VENDIDAS_2                         False       False
# NUMERO_DE_UNIDADES_VENDIDAS_3                         False       False
# NUMERO_DE_UNIDADES_VENDIDAS_4                         False       False
# NUMERO_DE_UNIDADES_VENDIDAS_5                         False       False
# N_ZONA_NEG                                            False        True
# OBLIGACION                                             True        True
# OBSERVACIONES                                         False       False
# OBSERVACIONES_DEL_ACTIVO_FIJO_1                       False       False
# OBSERVACIONES_DEL_ACTIVO_FIJO_2                       False       False
# OBSERVACIONES_DEL_ACTIVO_FIJO_3                       False       False
# OCUPACION                                             False       False
# OFICIO                                                False       False
# OTROS                                                  True        True
# OTROS_INGRESOS                                        False       False
# PAGARE                                                 True        True
# PAIS_MONEDA_EXTRANJERA                                False       False
# PERIODICIDAD_PAGO                                      True        True
# PERSONA_FALLECIDA                                     False       False
# POBLACION_VULNERABLE                                  False       False
# PORCENTAJE_PAGO                                        True        True
# POSEE_CUENTAS_EN_MONEDA_EXTRANJERA                    False       False
# PROFESION                                              True        True
# P_MYPIME                                              False        True
# RANGO_PAGO                                             True       False
# REALIZA_OPERACIONES_EN_MONEDA_EXTRANJERA              False       False
# REFERENCIA_UBICACION_DEL_NEGOCIO                      False       False
# REGIMEN_DE_IMPUESTOS                                  False       False
# REGIMEN_DE_IVA                                        False       False
# REGIMEN_DE_RENTA                                      False       False
# REGION                                                 True       False
# REGIONAL                                              False       False
# REGION_1                                               True       False
# REGION_CLIENTE                                        False        True
# REGION_REAL                                            True       False
# RESPONSABLE_DE_HOGAR                                  False       False
# SALDO                                                  True        True
# SEGURO_VIDA                                            True        True
# SOLICITUD                                             False       False
# SUCURSAL                                               True        True
# SUCURSALES                                             True       False
# SUCURSAL_1                                             True       False
# SUCURSAL_COD                                           True       False
# SUCURSAL_CONTABILIZA                                  False       False
# SUCURSAL_REAL                                          True       False
# SUELDO_BASICO                                         False       False
# TASA_ANUAL                                             True        True
# TASA_PERIODICA                                         True        True
# TELEFONO                                              False       False
# TELEFONO_EMPRESA                                      False       False
# TELEFONO_PARTICULAR                                   False       False
# TEL_FIJO                                               True        True
# TEL_NEGOCIO                                           False        True
# TIPO                                                   True        True
# TIPO_CLIENTE                                           True        True
# TIPO_CLIENTE_COD                                       True        True
# TIPO_CREDITO                                           True        True
# TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_1     False       False
# TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_2     False       False
# TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_3     False       False
# TIPO_DE_CLIENTE                                       False       False
# TIPO_DE_CONTRATO                                      False       False
# TIPO_DE_CONTRIBUYENTE                                 False       False
# TIPO_DE_CUENTA_BANCARIA                               False       False
# TIPO_DE_IDENTIFICACION                                False       False
# TIPO_DE_INVENTARIO_1                                  False       False
# TIPO_DE_INVENTARIO_2                                  False       False
# TIPO_DE_INVENTARIO_3                                  False       False
# TIPO_DE_INVENTARIO_4                                  False       False
# TIPO_DE_INVENTARIO_5                                  False       False
# TIPO_DE_INVENTARIO_6                                  False       False
# TIPO_DE_PASIVO_1                                      False       False
# TIPO_DE_PASIVO_2                                      False       False
# TIPO_DE_PASIVO_3                                      False       False
# TIPO_DE_PASIVO_4                                      False       False
# TIPO_DE_VENTAS_QUE_REALIZA                            False       False
# TIPO_DOCUMENTO                                        False       False
# TIPO_OBLIGA                                           False       False
# TIPO_UBICACION                                         True        True
# TIPO_VIVIENDA                                         False       False
# UBICACION_2                                           False       False
# VALOR_COMERCIAL_1                                     False       False
# VALOR_COMERCIAL_2                                     False       False
# VALOR_COMERCIAL_3                                     False       False
# VALOR_CUOTA                                            True        True
# VALOR_DEL_CAMPO_ADICIONAL                             False       False
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_1               False       False
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_2               False       False
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_3               False       False
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_4               False       False
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_5               False       False
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...    False       False
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...    False       False
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...    False       False
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...    False       False
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...    False       False
# VALOR_DESEMBOLSADO                                    False       False
# VALOR_DE_LA_CUOTA_1                                   False       False
# VALOR_DE_LA_CUOTA_2                                   False       False
# VALOR_DE_LA_CUOTA_3                                   False       False
# VALOR_DE_LA_CUOTA_4                                   False       False
# VALOR_DE_LA_CUOTA_ACTUAL_1                            False       False
# VALOR_DE_LA_CUOTA_ACTUAL_2                            False       False
# VALOR_DE_LA_CUOTA_ACTUAL_3                            False       False
# VALOR_DE_LA_CUOTA_ACTUAL_4                            False       False
# VALOR_DE_LA_GARANTIA_1                                False       False
# VALOR_DE_LA_GARANTIA_2                                False       False
# VALOR_DE_LA_GARANTIA_3                                False       False
# VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_1                    False       False
# VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_2                    False       False
# VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_3                    False       False
# VALOR_OTROS_DESCUENTOS_DE_NOMINA                      False       False
# VALOR_REFINANCIADO                                    False       False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...    False       False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...    False       False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...    False       False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...    False       False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...    False       False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...    False       False
# VENCIDA                                                True       False
# VENCIMIENTO_DEL_CONTRATO                              False       False
# ZONA                                                  False       False
#
#                                                     COLOCACION_NEW  CONTACTO  \
# ACTIVIDAD                                                    False     False
# ACTIVIDAD_CIIU_PRIMARIA                                      False      True
# ACTIVIDAD_ECONOMICA                                          False      True
# ADMINISTRA_RECURSOS_PUBLICOS                                 False      True
# ANO_CONTABILIZA                                               True     False
# ARRENDADOR_DEL_NEGOCIO                                       False     False
# ASIGNADO_A                                                   False      True
# AUTORIZA_EL_ENVIO_DE_INFORMACION_POR_MEDIO_DE_C...           False      True
# AUTORIZA_LA_CONSULTA_EN_LAS_CENTRALES_DE_RIESGO              False      True
# BANCO_MONEDA_EXTRANJERA                                      False      True
# BARRIO                                                       False     False
# BARRIO_COMERCIAL                                             False      True
# BARRIO_NEGOCIO                                               False     False
# BARRIO_RESIDENCIA                                            False      True
# BUS_REGION                                                   False     False
# CALIFICACION_CIERRE                                          False     False
# CANTIDAD_DE_INVENTARIO_1                                     False     False
# CANTIDAD_DE_INVENTARIO_2                                     False     False
# CANTIDAD_DE_INVENTARIO_3                                     False     False
# CANTIDAD_DE_INVENTARIO_4                                     False     False
# CANTIDAD_DE_INVENTARIO_5                                     False     False
# CANTIDAD_DE_INVENTARIO_6                                     False     False
# CAPITAL_VEN                                                  False     False
# CEDULA                                                        True     False
# CELULAR                                                       True     False
# CENTRO_DE_COSTO                                              False      True
# CIUDAD                                                       False     False
# CIUDAD_COMERCIAL                                             False      True
# CIUDAD_EMPRESA                                               False      True
# CIUDAD_RESIDENCIA                                            False      True
# CLIENTE                                                      False      True
# CODEUDOR                                                      True     False
# CODIGO_DEL_CAMPO_ADICIONAL_DEL_NEGOCIO                       False     False
# COD_DESTINACION                                               True     False
# COD_LINEA                                                     True     False
# COD_MODALIDAD                                                 True     False
# COD_USUARIO_APR                                               True     False
# COMISION                                                     False     False
# CORREO                                                        True     False
# CREDITOS_VIGENTES                                             True     False
# CUENTA_MONEDA_EXTRANJERA                                     False      True
# CUOTAS_PACTADAS                                              False     False
# CUOTAS_PENDIENTES                                            False     False
# DECLARA_RENTA                                                False      True
# DESCRIPCION                                                  False     False
# DESCRIPCION_DEL_ACREEDOR_1                                   False     False
# DESCRIPCION_DEL_ACREEDOR_2                                   False     False
# DESCRIPCION_DEL_ACREEDOR_3                                   False     False
# DESCRIPCION_DEL_ACREEDOR_4                                   False     False
# DESCRIPCION_DEL_ACTIVO_FIJO_1                                False     False
# DESCRIPCION_DEL_ACTIVO_FIJO_2                                False     False
# DESCRIPCION_DEL_ACTIVO_FIJO_3                                False     False
# DESCRIPCION_DEL_PRODUCTO_1                                   False     False
# DESCRIPCION_DEL_PRODUCTO_2                                   False     False
# DESCRIPCION_DEL_PRODUCTO_3                                   False     False
# DESCRIPCION_DEL_PRODUCTO_4                                   False     False
# DESCRIPCION_DEL_PRODUCTO_5                                   False     False
# DESCRIPCION_DEL_PRODUCTO_6                                   False     False
# DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_1                  False     False
# DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_2                  False     False
# DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_3                  False     False
# DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_4                  False     False
# DESCRIPCION_DEL_PRODUCTO_QUE_COMERCIALIZA_5                  False     False
# DESCRIPCION_DE_LAS_OPERACIONES_EN_MONEDA_EXTRAN...           False      True
# DESCRIPCION_OTROS_INGRESOS                                   False      True
# DESTINACION                                                   True     False
# DESTINO_DEL_PASIVO_1                                         False     False
# DESTINO_DEL_PASIVO_2                                         False     False
# DESTINO_DEL_PASIVO_3                                         False     False
# DESTINO_DEL_PASIVO_4                                         False     False
# DIAS_CICLO_CREDITO                                            True     False
# DIAS_LABORADOS_POR_SEMANA                                    False     False
# DIAS_VENCIDO                                                 False     False
# DIRECCION                                                     True     False
# DIRECCION_COMERCIAL                                          False      True
# DIRECCION_DE_RESIDENCIA                                      False      True
# DIRECCION_EMPRESA                                            False      True
# DIR_CORRESPONDENCIA                                          False      True
# DIR_NEGOCIO                                                  False     False
# DOC_CONTABILIZA                                               True     False
# EDAD                                                          True     False
# EGRESOS_MENSUALES                                            False      True
# EJECUTIVO_ACTUAL                                             False     False
# EMAIL                                                        False      True
# EMPRESA_DONDE_TRABAJA                                        False      True
# ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PREN...           False     False
# ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PREN...           False     False
# ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PREN...           False     False
# ENTIDAD_FINANCIERA                                           False      True
# ESTADO                                                        True     False
# ESTADO_CIVIL                                                  True      True
# ESTRATO                                                       True     False
# EST_SOLICITUD                                                 True     False
# FACTORRH                                                     False     False
# FAX                                                          False      True
# FAX_EMPRESA                                                  False      True
# FECHA_APROBA                                                  True     False
# FECHA_DESEMBOLSO                                              True     False
# FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_1                       False     False
# FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_2                       False     False
# FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_3                       False     False
# FECHA_DE_EXPEDICION_CEDULA                                   False      True
# FECHA_DE_INICIO_DEL_NEGOCIO                                  False     False
# FECHA_EN_EL_ACTUAL_LUGAR_DE_UBICACION                        False     False
# FECHA_NACIMIENTO                                              True      True
# FECHA_PAGO                                                    True     False
# FECHA_PROXIMO_PAGO                                           False     False
# FECHA_SOLICITUD                                               True     False
# FECHA_ULT_PAGO                                               False     False
# FECHA_UTL_ACTUALIZACION                                      False     False
# FECHA_VENCIMIENTO_FINAL                                      False     False
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_1                           False     False
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_2                           False     False
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_3                           False     False
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_4                           False     False
# GARANTIA_REAL                                                False     False
# GENERO                                                        True      True
# IDENTI_EJECUTIVO                                              True     False
# INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_1                    False     False
# INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_2                    False     False
# INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_3                    False     False
# INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOC...           False     False
# INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOC...           False     False
# INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOC...           False     False
# INGRESO_ABRIL                                                False     False
# INGRESO_AGOSTO                                               False     False
# INGRESO_DICIEMBRE                                            False     False
# INGRESO_ENERO                                                False     False
# INGRESO_FEBRERO                                              False     False
# INGRESO_JULIO                                                False     False
# INGRESO_JUNIO                                                False     False
# INGRESO_MARZO                                                False     False
# INGRESO_MAYO                                                 False     False
# INGRESO_MENSUAL                                              False      True
# INGRESO_NOVIEMBRE                                            False     False
# INGRESO_OCTUBRE                                              False     False
# INGRESO_SEPTIEMBRE                                           False     False
# INTERES_VEN                                                  False     False
# JORNADA_LABORAL                                              False      True
# K_ZONA_NEG                                                   False     False
# LINEA                                                         True     False
# LUGAR_DE_EXPEDICION                                          False      True
# MEDIO_DE_PAGO                                                False      True
# METODO_DEL_CALCULO_DE_COSTO_DE_VENTA                         False     False
# MODALIDAD                                                     True     False
# MODELO_DEL_VEHICULO_1                                        False     False
# MODELO_DEL_VEHICULO_2                                        False     False
# MODELO_DEL_VEHICULO_3                                        False     False
# MONEDA                                                       False      True
# MONTO                                                         True     False
# MONTO_DE_LA_DEUDA_1                                          False     False
# MONTO_DE_LA_DEUDA_2                                          False     False
# MONTO_DE_LA_DEUDA_3                                          False     False
# MONTO_DE_LA_DEUDA_4                                          False     False
# MORA                                                         False     False
# MOVIL                                                        False      True
# MUJER_CABEZA                                                 False      True
# MUNICIPIO                                                     True     False
# MUNICIPIO_CLIENTE                                            False     False
# NATURALEZA                                                   False      True
# NEGOCIO                                                      False     False
# NIVEL_ESTUDIOS                                                True      True
# NOMBRE                                                        True     False
# NOMBRE_DEL_CARGO_QUE_DESEMPENA_EN_LA_EMPRESA                 False      True
# NOMBRE_DEL_NEGOCIO                                           False     False
# NOMBRE_EJECUTIVO                                              True     False
# NOMBRE_USUARIO                                                True     False
# NRO_CUOTAS                                                    True     False
# NRO_SOLICITUD                                                False     False
# NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE...           False     False
# NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE...           False     False
# NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE...           False     False
# NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIV...           False     False
# NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIV...           False     False
# NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIV...           False     False
# NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PAR...           False     False
# NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PAR...           False     False
# NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PAR...           False     False
# NUMERO_DE_UNIDADES_VENDIDAS_1                                False     False
# NUMERO_DE_UNIDADES_VENDIDAS_2                                False     False
# NUMERO_DE_UNIDADES_VENDIDAS_3                                False     False
# NUMERO_DE_UNIDADES_VENDIDAS_4                                False     False
# NUMERO_DE_UNIDADES_VENDIDAS_5                                False     False
# N_ZONA_NEG                                                   False     False
# OBLIGACION                                                    True     False
# OBSERVACIONES                                                 True     False
# OBSERVACIONES_DEL_ACTIVO_FIJO_1                              False     False
# OBSERVACIONES_DEL_ACTIVO_FIJO_2                              False     False
# OBSERVACIONES_DEL_ACTIVO_FIJO_3                              False     False
# OCUPACION                                                    False      True
# OFICIO                                                       False      True
# OTROS                                                        False     False
# OTROS_INGRESOS                                               False      True
# PAGARE                                                       False     False
# PAIS_MONEDA_EXTRANJERA                                       False      True
# PERIODICIDAD_PAGO                                             True     False
# PERSONA_FALLECIDA                                            False      True
# POBLACION_VULNERABLE                                         False      True
# PORCENTAJE_PAGO                                              False     False
# POSEE_CUENTAS_EN_MONEDA_EXTRANJERA                           False      True
# PROFESION                                                     True      True
# P_MYPIME                                                     False     False
# RANGO_PAGO                                                   False     False
# REALIZA_OPERACIONES_EN_MONEDA_EXTRANJERA                     False      True
# REFERENCIA_UBICACION_DEL_NEGOCIO                             False     False
# REGIMEN_DE_IMPUESTOS                                         False      True
# REGIMEN_DE_IVA                                               False      True
# REGIMEN_DE_RENTA                                             False      True
# REGION                                                        True     False
# REGIONAL                                                     False      True
# REGION_1                                                     False     False
# REGION_CLIENTE                                               False     False
# REGION_REAL                                                  False     False
# RESPONSABLE_DE_HOGAR                                         False      True
# SALDO                                                        False     False
# SEGURO_VIDA                                                  False     False
# SOLICITUD                                                     True     False
# SUCURSAL                                                      True      True
# SUCURSALES                                                   False     False
# SUCURSAL_1                                                   False     False
# SUCURSAL_COD                                                  True     False
# SUCURSAL_CONTABILIZA                                          True     False
# SUCURSAL_REAL                                                False     False
# SUELDO_BASICO                                                False      True
# TASA_ANUAL                                                    True     False
# TASA_PERIODICA                                               False     False
# TELEFONO                                                     False     False
# TELEFONO_EMPRESA                                             False      True
# TELEFONO_PARTICULAR                                          False      True
# TEL_FIJO                                                      True     False
# TEL_NEGOCIO                                                  False     False
# TIPO                                                         False     False
# TIPO_CLIENTE                                                 False     False
# TIPO_CLIENTE_COD                                             False     False
# TIPO_CREDITO                                                  True     False
# TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_1            False     False
# TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_2            False     False
# TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_3            False     False
# TIPO_DE_CLIENTE                                              False      True
# TIPO_DE_CONTRATO                                             False      True
# TIPO_DE_CONTRIBUYENTE                                        False      True
# TIPO_DE_CUENTA_BANCARIA                                      False      True
# TIPO_DE_IDENTIFICACION                                       False      True
# TIPO_DE_INVENTARIO_1                                         False     False
# TIPO_DE_INVENTARIO_2                                         False     False
# TIPO_DE_INVENTARIO_3                                         False     False
# TIPO_DE_INVENTARIO_4                                         False     False
# TIPO_DE_INVENTARIO_5                                         False     False
# TIPO_DE_INVENTARIO_6                                         False     False
# TIPO_DE_PASIVO_1                                             False     False
# TIPO_DE_PASIVO_2                                             False     False
# TIPO_DE_PASIVO_3                                             False     False
# TIPO_DE_PASIVO_4                                             False     False
# TIPO_DE_VENTAS_QUE_REALIZA                                   False     False
# TIPO_DOCUMENTO                                                True     False
# TIPO_OBLIGA                                                   True     False
# TIPO_UBICACION                                                True      True
# TIPO_VIVIENDA                                                 True      True
# UBICACION_2                                                  False      True
# VALOR_COMERCIAL_1                                            False     False
# VALOR_COMERCIAL_2                                            False     False
# VALOR_COMERCIAL_3                                            False     False
# VALOR_CUOTA                                                   True     False
# VALOR_DEL_CAMPO_ADICIONAL                                    False     False
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_1                      False     False
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_2                      False     False
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_3                      False     False
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_4                      False     False
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_5                      False     False
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...           False     False
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...           False     False
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...           False     False
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...           False     False
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...           False     False
# VALOR_DESEMBOLSADO                                            True     False
# VALOR_DE_LA_CUOTA_1                                          False     False
# VALOR_DE_LA_CUOTA_2                                          False     False
# VALOR_DE_LA_CUOTA_3                                          False     False
# VALOR_DE_LA_CUOTA_4                                          False     False
# VALOR_DE_LA_CUOTA_ACTUAL_1                                   False     False
# VALOR_DE_LA_CUOTA_ACTUAL_2                                   False     False
# VALOR_DE_LA_CUOTA_ACTUAL_3                                   False     False
# VALOR_DE_LA_CUOTA_ACTUAL_4                                   False     False
# VALOR_DE_LA_GARANTIA_1                                       False     False
# VALOR_DE_LA_GARANTIA_2                                       False     False
# VALOR_DE_LA_GARANTIA_3                                       False     False
# VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_1                           False     False
# VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_2                           False     False
# VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_3                           False     False
# VALOR_OTROS_DESCUENTOS_DE_NOMINA                             False      True
# VALOR_REFINANCIADO                                            True     False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...           False     False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...           False     False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...           False     False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...           False     False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...           False     False
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...           False     False
# VENCIDA                                                      False     False
# VENCIMIENTO_DEL_CONTRATO                                     False      True
# ZONA                                                         False     False
#
#                                                     NEGOCIO  COUNTS
# ACTIVIDAD                                              True       1
# ACTIVIDAD_CIIU_PRIMARIA                               False       1
# ACTIVIDAD_ECONOMICA                                   False       1
# ADMINISTRA_RECURSOS_PUBLICOS                          False       1
# ANO_CONTABILIZA                                       False       1
# ARRENDADOR_DEL_NEGOCIO                                 True       1
# ASIGNADO_A                                             True       2
# AUTORIZA_EL_ENVIO_DE_INFORMACION_POR_MEDIO_DE_C...    False       1
# AUTORIZA_LA_CONSULTA_EN_LAS_CENTRALES_DE_RIESGO       False       1
# BANCO_MONEDA_EXTRANJERA                               False       1
# BARRIO                                                 True       1
# BARRIO_COMERCIAL                                      False       1
# BARRIO_NEGOCIO                                        False       1
# BARRIO_RESIDENCIA                                     False       1
# BUS_REGION                                            False       1
# CALIFICACION_CIERRE                                   False       2
# CANTIDAD_DE_INVENTARIO_1                               True       1
# CANTIDAD_DE_INVENTARIO_2                               True       1
# ...
# DIAS_VENCIDO                                          False       2
# DIRECCION                                              True       4
# DIRECCION_COMERCIAL                                   False       1
# DIRECCION_DE_RESIDENCIA                               False       1
# DIRECCION_EMPRESA                                     False       1
# DIR_CORRESPONDENCIA                                   False       1
# DIR_NEGOCIO                                           False       1
# DOC_CONTABILIZA                                       False       1
# EDAD                                                  False       3
# EGRESOS_MENSUALES                                     False       1
# EJECUTIVO_ACTUAL                                      False       1
# EMAIL                                                 False       1
# EMPRESA_DONDE_TRABAJA                                 False       1
# ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PREN...     True       1
# ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PREN...     True       1
# ENTIDAD_CON_LA_CUAL_TIENE_LA_HIPOTECA_O_LA_PREN...     True       1
# ENTIDAD_FINANCIERA                                    False       1
# ESTADO                                                 True       2
# ESTADO_CIVIL                                          False       4
# ESTRATO                                               False       3
# EST_SOLICITUD                                         False       1
# FACTORRH                                              False       2
# FAX                                                   False       1
# FAX_EMPRESA                                           False       1
# FECHA_APROBA                                          False       3
# FECHA_DESEMBOLSO                                      False       3
# FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_1                 True       1
# FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_2                 True       1
# FECHA_DE_ADQUISICION_DEL_ACTIVO_FIJO_3                 True       1
# FECHA_DE_EXPEDICION_CEDULA                            False       1
# FECHA_DE_INICIO_DEL_NEGOCIO                            True       1
# FECHA_EN_EL_ACTUAL_LUGAR_DE_UBICACION                  True       1
# FECHA_NACIMIENTO                                      False       4
# FECHA_PAGO                                            False       1
# FECHA_PROXIMO_PAGO                                    False       2
# FECHA_SOLICITUD                                       False       3
# FECHA_ULT_PAGO                                        False       2
# FECHA_UTL_ACTUALIZACION                               False       2
# FECHA_VENCIMIENTO_FINAL                               False       2
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_1                     True       1
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_2                     True       1
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_3                     True       1
# FRECUENCIA_DEL_VALOR_DE_LA_CUOTA_4                     True       1
# GARANTIA_REAL                                         False       2
# GENERO                                                False       4
# IDENTI_EJECUTIVO                                      False       1
# INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_1              True       1
# INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_2              True       1
# INDICADOR_SI_EL_ACTIVO_FIJO_ES_GARANTIA_3              True       1
# INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOC...     True       1
# INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOC...     True       1
# INDICADOR_SI_LOS_ACTIVOS_FIJOS_AFECTAN_AL_NEGOC...     True       1
# INGRESO_ABRIL                                          True       1
# INGRESO_AGOSTO                                         True       1
# INGRESO_DICIEMBRE                                      True       1
# INGRESO_ENERO                                          True       1
# INGRESO_FEBRERO                                        True       1
# INGRESO_JULIO                                          True       1
# INGRESO_JUNIO                                          True       1
# INGRESO_MARZO                                          True       1
# INGRESO_MAYO                                           True       1
# INGRESO_MENSUAL                                       False       1
# INGRESO_NOVIEMBRE                                      True       1
# INGRESO_OCTUBRE                                        True       1
# INGRESO_SEPTIEMBRE                                     True       1
# INTERES_VEN                                           False       2
# JORNADA_LABORAL                                       False       1
# K_ZONA_NEG                                            False       1
# LINEA                                                 False       3
# LUGAR_DE_EXPEDICION                                   False       1
# MEDIO_DE_PAGO                                         False       1
# METODO_DEL_CALCULO_DE_COSTO_DE_VENTA                   True       1
# MODALIDAD                                             False       3
# MODELO_DEL_VEHICULO_1                                  True       1
# MODELO_DEL_VEHICULO_2                                  True       1
# MODELO_DEL_VEHICULO_3                                  True       1
# MONEDA                                                False       1
# MONTO                                                 False       3
# MONTO_DE_LA_DEUDA_1                                    True       1
# MONTO_DE_LA_DEUDA_2                                    True       1
# MONTO_DE_LA_DEUDA_3                                    True       1
# MONTO_DE_LA_DEUDA_4                                    True       1
# MORA                                                  False       2
# MOVIL                                                 False       1
# MUJER_CABEZA                                          False       3
# MUNICIPIO                                             False       2
# MUNICIPIO_CLIENTE                                     False       2
# NATURALEZA                                            False       1
# NEGOCIO                                               False       1
# NIVEL_ESTUDIOS                                        False       4
# NOMBRE                                                False       2
# NOMBRE_DEL_CARGO_QUE_DESEMPENA_EN_LA_EMPRESA          False       1
# NOMBRE_DEL_NEGOCIO                                     True       1
# NOMBRE_EJECUTIVO                                      False       1
# NOMBRE_USUARIO                                        False       1
# NRO_CUOTAS                                            False       1
# NRO_SOLICITUD                                         False       2
# NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE...     True       1
# NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE...     True       1
# NUMERO_DE_LA_MATRICULA_INMOBILIARIA_EN_CASO_QUE...     True       1
# NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIV...     True       1
# NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIV...     True       1
# NUMERO_DE_LA_PLACA_EN_CASO_QUE_EL_TIPO_DE_ACTIV...     True       1
# NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PAR...     True       1
# NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PAR...     True       1
# NUMERO_DE_SERIAL_CUANDO_EL_ACTIVO_FIJO_HACE_PAR...     True       1
# NUMERO_DE_UNIDADES_VENDIDAS_1                          True       1
# NUMERO_DE_UNIDADES_VENDIDAS_2                          True       1
# NUMERO_DE_UNIDADES_VENDIDAS_3                          True       1
# NUMERO_DE_UNIDADES_VENDIDAS_4                          True       1
# NUMERO_DE_UNIDADES_VENDIDAS_5                          True       1
# N_ZONA_NEG                                            False       1
# OBLIGACION                                            False       3
# OBSERVACIONES                                         False       1
# OBSERVACIONES_DEL_ACTIVO_FIJO_1                        True       1
# OBSERVACIONES_DEL_ACTIVO_FIJO_2                        True       1
# OBSERVACIONES_DEL_ACTIVO_FIJO_3                        True       1
# OCUPACION                                             False       1
# OFICIO                                                False       1
# OTROS                                                 False       2
# OTROS_INGRESOS                                        False       1
# PAGARE                                                False       2
# PAIS_MONEDA_EXTRANJERA                                False       1
# PERIODICIDAD_PAGO                                     False       3
# PERSONA_FALLECIDA                                     False       1
# POBLACION_VULNERABLE                                  False       1
# PORCENTAJE_PAGO                                       False       2
# POSEE_CUENTAS_EN_MONEDA_EXTRANJERA                    False       1
# PROFESION                                             False       4
# P_MYPIME                                              False       1
# RANGO_PAGO                                            False       1
# REALIZA_OPERACIONES_EN_MONEDA_EXTRANJERA              False       1
# REFERENCIA_UBICACION_DEL_NEGOCIO                       True       1
# REGIMEN_DE_IMPUESTOS                                  False       1
# REGIMEN_DE_IVA                                        False       1
# REGIMEN_DE_RENTA                                      False       1
# REGION                                                False       2
# REGIONAL                                              False       1
# REGION_1                                              False       1
# REGION_CLIENTE                                        False       1
# REGION_REAL                                           False       1
# RESPONSABLE_DE_HOGAR                                  False       1
# SALDO                                                 False       2
# SEGURO_VIDA                                           False       2
# SOLICITUD                                             False       1
# SUCURSAL                                              False       4
# SUCURSALES                                            False       1
# SUCURSAL_1                                            False       1
# SUCURSAL_COD                                          False       2
# SUCURSAL_CONTABILIZA                                  False       1
# SUCURSAL_REAL                                         False       1
# SUELDO_BASICO                                         False       1
# TASA_ANUAL                                            False       3
# TASA_PERIODICA                                        False       2
# TELEFONO                                               True       1
# TELEFONO_EMPRESA                                      False       1
# TELEFONO_PARTICULAR                                   False       1
# TEL_FIJO                                              False       3
# TEL_NEGOCIO                                           False       1
# TIPO                                                   True       3
# TIPO_CLIENTE                                          False       2
# TIPO_CLIENTE_COD                                      False       2
# TIPO_CREDITO                                          False       3
# TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_1      True       1
# TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_2      True       1
# TIPO_DE_ACTIVO_FIJO_DEL_ESTUDIO_SOCIO-ECONOMICO_3      True       1
# TIPO_DE_CLIENTE                                       False       1
# TIPO_DE_CONTRATO                                      False       1
# TIPO_DE_CONTRIBUYENTE                                 False       1
# TIPO_DE_CUENTA_BANCARIA                               False       1
# TIPO_DE_IDENTIFICACION                                False       1
# TIPO_DE_INVENTARIO_1                                   True       1
# TIPO_DE_INVENTARIO_2                                   True       1
# TIPO_DE_INVENTARIO_3                                   True       1
# TIPO_DE_INVENTARIO_4                                   True       1
# TIPO_DE_INVENTARIO_5                                   True       1
# TIPO_DE_INVENTARIO_6                                   True       1
# TIPO_DE_PASIVO_1                                       True       1
# TIPO_DE_PASIVO_2                                       True       1
# TIPO_DE_PASIVO_3                                       True       1
# TIPO_DE_PASIVO_4                                       True       1
# TIPO_DE_VENTAS_QUE_REALIZA                             True       1
# TIPO_DOCUMENTO                                        False       1
# TIPO_OBLIGA                                           False       1
# TIPO_UBICACION                                        False       4
# TIPO_VIVIENDA                                         False       2
# UBICACION_2                                           False       1
# VALOR_COMERCIAL_1                                      True       1
# VALOR_COMERCIAL_2                                      True       1
# VALOR_COMERCIAL_3                                      True       1
# VALOR_CUOTA                                           False       3
# VALOR_DEL_CAMPO_ADICIONAL                              True       1
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_1                True       1
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_2                True       1
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_3                True       1
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_4                True       1
# VALOR_DEL_COSTO_UNITARIO_DEL_PRODUCTO_5                True       1
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...     True       1
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...     True       1
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...     True       1
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...     True       1
# VALOR_DEL_PRECIO_DE_VENTA_POR_UNIDAD_DEL_PRODUC...     True       1
# VALOR_DESEMBOLSADO                                    False       1
# VALOR_DE_LA_CUOTA_1                                    True       1
# VALOR_DE_LA_CUOTA_2                                    True       1
# VALOR_DE_LA_CUOTA_3                                    True       1
# VALOR_DE_LA_CUOTA_4                                    True       1
# VALOR_DE_LA_CUOTA_ACTUAL_1                             True       1
# VALOR_DE_LA_CUOTA_ACTUAL_2                             True       1
# VALOR_DE_LA_CUOTA_ACTUAL_3                             True       1
# VALOR_DE_LA_CUOTA_ACTUAL_4                             True       1
# VALOR_DE_LA_GARANTIA_1                                 True       1
# VALOR_DE_LA_GARANTIA_2                                 True       1
# VALOR_DE_LA_GARANTIA_3                                 True       1
# VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_1                     True       1
# VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_2                     True       1
# VALOR_DE_LA_HIPOTECA_O_LA_PRENDA_3                     True       1
# VALOR_OTROS_DESCUENTOS_DE_NOMINA                      False       1
# VALOR_REFINANCIADO                                    False       1
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...     True       1
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...     True       1
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...     True       1
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...     True       1
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...     True       1
# VALOR_UNITARIO_DEL_INVENTARIO_PARA_EL_ESTUDIO_S...     True       1
# VENCIDA                                               False       1
# VENCIMIENTO_DEL_CONTRATO                              False       1
# ZONA                                                   True       1
